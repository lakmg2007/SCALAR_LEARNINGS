# %% [markdown]
# <a href="https://colab.research.google.com/github/lakmg2007/SCALAR_LEARNINGS/blob/main/Probability_Assignment_Analyzing_Sachin_Tendulkar's_ODI_Career.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment
# #Analyzing Sachin Tendulkar's ODI Career
# #Conditional prob and bayes theorem
#
#
#
# ---
#
# ###1.   Addition Rule      :
# ###Formula : P(A∪B)=P(A)+P(B)−P(A∩B)
#
# ---
#
#
# ###2.   Multiplication Rule:
# ###Formula:P(A∩B)=P(A)⋅P(B∣A)
#
# ---
#
#
# ###3.   Marginal Probability:
# Probability of a single event happening (e.g., P(A) or P(B)).
#
# ---
#
#
# ###4.   Joint Probability:
# Probability of two events happening together (e.g., P(A ∩ B)).
#
#
# ---
#
#
# ###5.   Conditional Probability:
# Conditional probability calculates the likelihood of an event given that another event has already occurred.
# ####Formula:P(B∣A)=P(A∩B)/P(A)
#
#
# ---
#
#
# ###6.   Bayes' Theorem :
# Bayes' Theorem is a cornerstone of probability theory that helps us revise probabilities based on new evidence. It enables us to calculate conditional probabilities when the reverse probability and other relevant information are known.
# ###Formula for Bayes' Theorem
# The formula for Bayes' Theorem is:
# P(A∣B)=P(B∣A)⋅P(A)P(B)
#
# Where:
#
# P(A∣B) : Probability of  A  occurring given that  B  has occurred (posterior).
# P(B∣A) : Probability of  B  occurring given that  A  has occurred (likelihood).
# P(A) : Probability of  A  occurring (prior).
# P(B) : Probability of  B  occurring (evidence).

# %% [markdown]
# ---
#
#
# #Question1 : Neha has 4 yellow t-shirts, 6 black t-shirts, and 2 blue t-shirts to choose from for her outfit today. She chooses a t-shirt randomly with each t-shirt equally likely to be chosen.Find the probability that a black or blue t-shirt is chosen for the outfit.

# %%
#Addition Theorm shd be used i.e.  P(A∪B)=P(A)+P(B)−P(A∩B)
#P(A∪B) is the probability that A or B happens (i.e., black or blue t-shirt)
#𝑃(A) is the probability of a black t-shirt
#P(B) is the probability of a blue t-shirt
#P(A∩B) is the probability that both happen at the same time (overlap)
#total = 4+6+2 =12
P(A) = 6/12 = 1/2
P(B) = 2/12 = 1/6
P(A∩B) = 0
P(AUB) = 1/2 + 1/6 - 0 = 2/3

# %% [markdown]
# #Question2 : Based on the table given below, solve the following:
#
# ![image.png](data:image/png;base64,...)
#
# If a person is randomly selected out of 300 people, what is the probability that
#
# a. The person tested positive, given that he or she actually used marijuana?
#
# b. The person actually used marijuana, given that he or she tested positive?

# %%
# Conditional probability should be used  Formula:P(B∣A)=P(A∩B)/P(A)
a. The person tested positive, given that he or she actually used marijuana?

P(TestedPositive\UsedMarijuana)= Number who used and tested positive/Totalnumberwhoused marijuana
​ = 119/122 = 0.9754
# Out:
#   File "/tmp/ipython-input-1-1306172569.py", line 4
#     P(TestedPositive\UsedMarijuana)= Number who used and tested positive/Totalnumberwhoused marijuana
#                      ^
# SyntaxError: unexpected character after line continuation character

# %%
# Conditional probability should be used  Formula:P(B∣A)=P(A∩B)/P(A)
#b. The person actually used marijuana, given that he or she tested positive?
P(used marijuana/tested positive) = 119/143 = 0.8322

# %% [markdown]
# #Question 3: It is known that 70% people like plain tea, 60% people like ginger tea, and 30% like both.What percentage of the people like plain tea, but do not like ginger tea?

# %%
#The probability formula used here is based on set subtraction from set theory
#Formula Used:P(A only)=P(A)−P(A∩B) - subtraction rule
#Where:
#A: People who like plain tea
#B: People who like ginger tea
#A∩B: People who like both plain and ginger tea
#A only: People who like only plain tea (i.e., plain tea but not ginger tea)
P(Plain only)=P(Plain) - P(Plain ∩ inger)
= 70%-30%
=40%

# %% [markdown]
# #Question 4: Two dice are thrown, and their sum is recorded. What is the probability that the sum of observed oucome values is less than or equal to 5?

# %%
#Two fair dice are thrown. Each die has 6 faces (1 through 6).
#Each die has 6 outcomes, so total outcomes when throwing two dice:
6*6 =36
#Favorable outcomes:
#We want outcomes where the sum ≤ 5.

Dice 1	Dice 2	Sum
1	      1	       2
1	      2	       3
2	      1	       3
1	      3	       4
3	      1	       4
2	      2	       4
1	      4	       5
4	      1	       5
2	      3	       5
3	      2	       5

Total favorable outcomes = 10

Probability: P(sum≤5)= Favorable outcomes/Total outcomes
                     = 10/36 = 5/18

# %% [markdown]
# # Question5: Among 100 students, 60 have taken the computer vision (CV) module, 50 have taken natural language processing (NLP). Also, it is seen that 20 have taken both CV and NLP. Given that a person has taken NLP, what is the probability that he has also taken CV?

# %%
P(CV/NLP) = P(NLP ∩ CV )/P(NotImplementedType) = 20/50 =2/5 = 0.4 = 40%

# %% [markdown]
# #Question 6: A rare disease affects only 1 out of 1000 people. Upon conducting a diagnostic test to detect it, it is found that 90% of the affected people get a "positive" test result and that 5% of the non-affected people also get "positive" test result. Given that a person tested positive, what is the probability that he is actually affected?

# %%
#Positive and affected = 90%
#Positive and non-affected = 5%
#Bay's theorm
P(diseased∣Positive)= P(Positive∣diseased)⋅P(diseased) /P(Positive)

#Now lets calculate P(Positive)
Probability a person has the disease =1/1000 = 0.001
Probability of a person not diseased =1- 0.001=0.999
P(Positive|diseased)= 0.9
P(Positive|not-diseased) = 0.05

P(diseased∣Positive)= P(Positive∣diseased)⋅P(diseased) /P(Positive)
P(Positive) = P(Positive∣Disease)⋅P(Disease)+P(Positive∣No Disease)⋅P(No Disease)
            = 0.9 * 0.001 + 0.05 * 0.999
            = 0.0009+0.04995=0.05085
#Now applying Bay's theorm
P(diseased∣Positive)=0.9 * 0.001 /0.05085 0.0009/0.05085 = 0.0177 = 17.7 %

# %% [markdown]
# #Question 7 : It is known that 20% of Netflix users are premium subscribers.Also, 80% of premium subscribers watch at least one thriller movie per week, and 50% of basic subscribers watch at least one thriller movie per week.What is the probability that a Netflix subscriber who watches at least one thriller movie per week is a premium subscriber?

# %%
P(premium) = 20% = 0.20
P(Basic) = 80% = 0.80
P(Thriller|Premium) = 80% = 0.80
P(Thriller|Basic) = 50% = 0.5
#Need to find P(Thriller)
P(Thriller) = P(Thriller|Premium).P(Premium) + P(Thriller|Basic).P(Basic)
            = (0.8 * 0.2) + (0.5 * 0.8)
            = 0.16 + 0.40
            = 0.56
#Bay's theorm
P(Premium|Thriller) = P(Thriller|Premium).P(Premium)/P(Thriller)
                    = 0.8 * 0.2 / 0.56
                    = 0.16/0.56
                    = 0.2857
                    = 28.57%
